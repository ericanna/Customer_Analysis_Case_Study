# %%
import numpy as np
import pandas as pd

# %%
#Aggregate the data into one Data Frame using Pandas.
#Pay attention that files may have different names for the same column.
#therefore, make sure that you unify the columns names before concating them.
#Standardizing header names

file1 = pd.read_csv("file1.csv")
file2 = pd.read_csv("file2.csv")
file3 = pd.read_csv("file3.csv")

# %%
file1.rename(columns = {"ST": "State", "GENDER": "Gender"}, inplace=True)
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   State                      1071 non-null   object
#  2   Gender                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   object
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB

# %%
file2.rename(columns = {"ST": "State", "GENDER": "Gender"}, inplace=True)
file2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   996 non-null    object
#  1   State                      996 non-null    object
#  2   Gender                     991 non-null    object
#  3   Education                  996 non-null    object
#  4   Customer Lifetime Value    992 non-null    object
#  5   Income                     996 non-null    int64
#  6   Monthly Premium Auto       996 non-null    int64
#  7   Number of Open Complaints  996 non-null    object
#  8   Total Claim Amount         996 non-null    float64
#  9   Policy Type                996 non-null    object
#  10  Vehicle Class              996 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 85.7+ KB

# %%
file3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   7070 non-null   object
#  1   State                      7070 non-null   object
#  2   Customer Lifetime Value    7070 non-null   float64
#  3   Education                  7070 non-null   object
#  4   Gender                     7070 non-null   object
#  5   Income                     7070 non-null   int64
#  6   Monthly Premium Auto       7070 non-null   int64
#  7   Number of Open Complaints  7070 non-null   int64
#  8   Policy Type                7070 non-null   object
#  9   Total Claim Amount         7070 non-null   float64
#  10  Vehicle Class              7070 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 607.7+ KB

# %%
customer_df = pd.concat([file1,file2,file3], axis=0)
customer_df = customer_df.reset_index()
customer_df
# Out:
#        index Customer       State Gender             Education  \
# 0          0  RB50392  Washington    NaN                Master
# 1          1  QZ44356     Arizona      F              Bachelor
# 2          2  AI49188      Nevada      F              Bachelor
# 3          3  WW63253  California      M              Bachelor
# 4          4  GA49547  Washington      M  High School or Below
# ...      ...      ...         ...    ...                   ...
# 12069   7065  LA72316  California      M              Bachelor
# 12070   7066  PK87824  California      F               College
# 12071   7067  TD14365  California      M              Bachelor
# 12072   7068  UP19263  California      M               College
# 12073   7069  Y167826  California      M               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# 3                  764586.18%      0.0                 106.0
# 4                  536307.65%  36357.0                  68.0
# ...                       ...      ...                   ...
# 12069             23405.98798  71941.0                  73.0
# 12070             3096.511217  21604.0                  79.0
# 12071             8163.890428      0.0                  85.0
# 12072             7524.442436  21941.0                  96.0
# 12073             2611.836866      0.0                  77.0
#
#       Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                        1/0/00   Personal Auto  Four-Door Car
# 1                        1/0/00   Personal Auto  Four-Door Car
# 2                        1/0/00   Personal Auto   Two-Door Car
# 3                        1/0/00  Corporate Auto            SUV
# 4                        1/0/00   Personal Auto  Four-Door Car
# ...                         ...             ...            ...
# 12069                         0   Personal Auto  Four-Door Car
# 12070                         0  Corporate Auto  Four-Door Car
# 12071                         3  Corporate Auto  Four-Door Car
# 12072                         0   Personal Auto  Four-Door Car
# 12073                         0  Corporate Auto   Two-Door Car
#
#        Total Claim Amount
# 0                2.704934
# 1             1131.464935
# 2              566.472247
# 3              529.881344
# 4               17.269323
# ...                   ...
# 12069          198.234764
# 12070          379.200000
# 12071          790.784983
# 12072          691.200000
# 12073          369.600000
#
# [12074 rows x 12 columns]

# %%
#Deleting and rearranging columns
#– delete the column customer as it is only a unique identifier for each row of data

customer_df = customer_df.drop(columns=["Customer"])
customer_df
# Out:
#        index       State Gender             Education Customer Lifetime Value  \
# 0          0  Washington    NaN                Master                     NaN
# 1          1     Arizona      F              Bachelor              697953.59%
# 2          2      Nevada      F              Bachelor             1288743.17%
# 3          3  California      M              Bachelor              764586.18%
# 4          4  Washington      M  High School or Below              536307.65%
# ...      ...         ...    ...                   ...                     ...
# 12069   7065  California      M              Bachelor             23405.98798
# 12070   7066  California      F               College             3096.511217
# 12071   7067  California      M              Bachelor             8163.890428
# 12072   7068  California      M               College             7524.442436
# 12073   7069  California      M               College             2611.836866
#
#         Income  Monthly Premium Auto Number of Open Complaints  \
# 0          0.0                1000.0                    1/0/00
# 1          0.0                  94.0                    1/0/00
# 2      48767.0                 108.0                    1/0/00
# 3          0.0                 106.0                    1/0/00
# 4      36357.0                  68.0                    1/0/00
# ...        ...                   ...                       ...
# 12069  71941.0                  73.0                         0
# 12070  21604.0                  79.0                         0
# 12071      0.0                  85.0                         3
# 12072  21941.0                  96.0                         0
# 12073      0.0                  77.0                         0
#
#           Policy Type  Vehicle Class  Total Claim Amount
# 0       Personal Auto  Four-Door Car            2.704934
# 1       Personal Auto  Four-Door Car         1131.464935
# 2       Personal Auto   Two-Door Car          566.472247
# 3      Corporate Auto            SUV          529.881344
# 4       Personal Auto  Four-Door Car           17.269323
# ...               ...            ...                 ...
# 12069   Personal Auto  Four-Door Car          198.234764
# 12070  Corporate Auto  Four-Door Car          379.200000
# 12071  Corporate Auto  Four-Door Car          790.784983
# 12072   Personal Auto  Four-Door Car          691.200000
# 12073  Corporate Auto   Two-Door Car          369.600000
#
# [12074 rows x 11 columns]

# %%
#Removing duplicates

customer_df = customer_df.drop_duplicates()
customer_df = customer_df.reset_index()
customer_df
# Out:
#        level_0  index       State Gender             Education  \
# 0            0      0  Washington    NaN                Master
# 1            1      1     Arizona      F              Bachelor
# 2            2      2      Nevada      F              Bachelor
# 3            3      3  California      M              Bachelor
# 4            4      4  Washington      M  High School or Below
# ...        ...    ...         ...    ...                   ...
# 12069    12069   7065  California      M              Bachelor
# 12070    12070   7066  California      F               College
# 12071    12071   7067  California      M              Bachelor
# 12072    12072   7068  California      M               College
# 12073    12073   7069  California      M               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# 3                  764586.18%      0.0                 106.0
# 4                  536307.65%  36357.0                  68.0
# ...                       ...      ...                   ...
# 12069             23405.98798  71941.0                  73.0
# 12070             3096.511217  21604.0                  79.0
# 12071             8163.890428      0.0                  85.0
# 12072             7524.442436  21941.0                  96.0
# 12073             2611.836866      0.0                  77.0
#
#       Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                        1/0/00   Personal Auto  Four-Door Car
# 1                        1/0/00   Personal Auto  Four-Door Car
# 2                        1/0/00   Personal Auto   Two-Door Car
# 3                        1/0/00  Corporate Auto            SUV
# 4                        1/0/00   Personal Auto  Four-Door Car
# ...                         ...             ...            ...
# 12069                         0   Personal Auto  Four-Door Car
# 12070                         0  Corporate Auto  Four-Door Car
# 12071                         3  Corporate Auto  Four-Door Car
# 12072                         0   Personal Auto  Four-Door Car
# 12073                         0  Corporate Auto   Two-Door Car
#
#        Total Claim Amount
# 0                2.704934
# 1             1131.464935
# 2              566.472247
# 3              529.881344
# 4               17.269323
# ...                   ...
# 12069          198.234764
# 12070          379.200000
# 12071          790.784983
# 12072          691.200000
# 12073          369.600000
#
# [12074 rows x 12 columns]

# %%
#Working with data types – Check the data types of all the columns and fix the incorrect ones
#(for ex. customer lifetime value and number of open complaints ).
#Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.

customer_df.info()
customer_df["Customer Lifetime Value"].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   level_0                    12074 non-null  int64
#  1   index                      12074 non-null  int64
#  2   State                      9137 non-null   object
#  3   Gender                     9015 non-null   object
#  4   Education                  9137 non-null   object
#  5   Customer Lifetime Value    9130 non-null   object
#  6   Income                     9137 non-null   float64
#  7   Monthly Premium Auto       9137 non-null   float64
#  8   Number of Open Complaints  0 non-null      float64
#  9   Policy Type                9137 non-null   object
#  10  Vehicle Class              9137 non-null   object
#  11  Total Claim Amount         9137 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 1.1+ MB
# array([nan, '697953.59%', '1288743.17%', ..., 8163.890428, 7524.442436,
#        2611.836866], dtype=object)
