# %%
##Importing the necessary libraries: Pandas, Numpy, Matplotlib and Seaborn.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
##Importing a csv file with the workable data do Python.

clean_df = pd.read_csv("Data_Marketing_Customer_Analysis_Round3.csv")
clean_df2 = pd.read_csv("Data_Marketing_Customer_Analysis_Round3.csv")
clean_df
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   region                         10689 non-null  object
#  1   customer_lifetime_value        10689 non-null  int64
#  2   response                       10689 non-null  object
#  3   coverage                       10689 non-null  object
#  4   education                      10689 non-null  object
#  5   effective_to_date              10689 non-null  object
#  6   month                          10689 non-null  object
#  7   employment_status              10689 non-null  object
#  8   gender                         10689 non-null  object
#  9   income                         10689 non-null  int64
#  10  location_code                  10689 non-null  object
#  11  marital_status                 10689 non-null  object
# ...

# %%
# Activity: Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals.

## Using the np.number and object methods to segregate the numerical data types and categorical data types respectively.

numerical_df = clean_df.select_dtypes(include=np.number)
categorical_df = clean_df.select_dtypes(include=object)
numerical_df
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %%
categorical_df
# Out:
#             region response  coverage education effective_to_date month  \
# 0          central       no     basic   college           2/18/11   feb
# 1      west region       no     basic   college           1/18/11   jan
# 2             east       no     basic  bachelor           2/10/11   feb
# 3       north west      yes  extended   college           1/11/11   jan
# 4       north west       no   premium  bachelor           1/17/11   jan
# ...            ...      ...       ...       ...               ...   ...
# 10684      central       no   premium  bachelor           1/19/11   jan
# 10685   north west       no     basic   college            1/6/11   jan
# 10686      central       no  extended  bachelor            2/6/11   feb
# 10687  west region       no   premium   college           2/13/11   feb
# 10688      central       no     basic  bachelor            1/8/11   jan
#
#       employment_status gender location_code marital_status     policy_type  \
# ...

# %%
# Activity: Use Matplotlib to construct histograms.

## Simple use of the .hist method in the dataframe that contains only numerical columns.

numerical_df.hist(figsize=(10,12))
# Out:
# array([[<AxesSubplot:title={'center':'customer_lifetime_value'}>,
#         <AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'monthly_premium_auto'}>],
#        [<AxesSubplot:title={'center':'months_since_last_claim'}>,
#         <AxesSubplot:title={'center':'months_since_policy_inception'}>,
#         <AxesSubplot:title={'center':'number_of_open_complaints'}>],
#        [<AxesSubplot:title={'center':'number_of_policies'}>,
#         <AxesSubplot:title={'center':'total_claim_amount'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
# Activity: Use seaborn library to construct distribution plots for the numerical variables.

## Simple use of the sns.displot method in the dataframe that contains only numerical columns. The shape of the...
## ...graphics allows to check the normality of the values.

sns.displot(numerical_df["customer_lifetime_value"])
sns.displot(numerical_df["income"])

# %%
sns.displot(numerical_df["monthly_premium_auto"])
sns.displot(numerical_df["months_since_last_claim"])

# %%
sns.displot(numerical_df["months_since_policy_inception"])
sns.displot(numerical_df["number_of_open_complaints"])

# %%
sns.displot(numerical_df["number_of_policies"])
sns.displot(numerical_df["total_claim_amount"])

# %%
# Activity: For the numerical variables, check for correlation between the input features (not include the target feature).

## Creating a new dataframe without the column total_claim_amount, since she is the target feature. Then, appyling...
## ... the .corr() function, to return the correlations in a range of -1 to 1.

numerical_df2 = numerical_df.drop(columns = ["total_claim_amount"])
numerical_df2.corr()
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.003732
# income                                        0.003732  1.000000
# monthly_premium_auto                          0.404235 -0.002431
# months_since_last_claim                       0.011912 -0.026564
# months_since_policy_inception                 0.017055  0.003846
# number_of_open_complaints                    -0.032371  0.018903
# number_of_policies                            0.016789 -0.004461
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.404235                 0.011912
# income                                    -0.002431                -0.026564
# monthly_premium_auto                       1.000000                 0.010036
# months_since_last_claim                    0.010036                 1.000000
# ...

# %%
# Activity: Plot the Correlation Heatmap.

heatmap = sns.heatmap(numerical_df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Customer Heatmap', fontdict={'fontsize':12}, pad=12)

numerical_df.corr().to_csv("../correlations.csv")

# %%
# Activity: Show a plot of the total number of responses.

sns.histplot(categorical_df["response"])
# Out:
# <AxesSubplot:xlabel='response', ylabel='Count'>

# %%
# Activity: Show a plot of the response by the sales channel.

## Used "hue" since we are now working with two variables.

sns.countplot(x='sales_channel', hue='response', data=categorical_df)
plt.xlabel("Sales Channel")
plt.ylabel("Count")
plt.legend(title="Response")
plt.title("Response by Sales Channel")
# Out:
# Text(0.5, 1.0, 'Response by Sales Channel')

# %%
# Activity: Show a plot of the response by the total claim amount.

## First transformed the total_claim_amount, that comes in thousands of diferent values, in ranges of value. To do...
## ... that, need to check the actual range of the values, by applying the .min and .max methods.

print(numerical_df["total_claim_amount"].min())
print(numerical_df["total_claim_amount"].max())


def ranges_claim(value):
    if value >= 0 and value <= 100:
        return 0
    elif value > 100 and value <= 500:
        return 1
    elif value > 500 and value <= 1000:
        return 2
    elif value > 1000 and value <= 1500:
        return 3
    elif value > 1500 and value <= 2000:
        return 4
    else:
        return 5
# Out:
# 0
# 2893

# %%
clean_df["total_claim_amount"] = list(map(ranges_claim, clean_df["total_claim_amount"]))

## Then used "hue", since working with two variables.

sns.countplot(x='total_claim_amount', hue='response', data=clean_df)
plt.xlabel("Total Claim Amount")
plt.ylabel("Count")
plt.legend(title="Response", loc="upper right",fontsize=12)
plt.title("Response by Total Claim Amount")
plt.xticks(ticks=np.arange(6),labels=["$0 - $100,00", "$100,01 - $500,00","$500,01 - $1000,00","$1000,01 - $1500,00","$1500,01 - $2000,00", "More then $2000,00"],rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7fcd13c16ac0>,
# ...
#  [Text(0, 0, '$0 - $100,00'),
#   Text(1, 0, '$100,01 - $500,00'),
#   Text(2, 0, '$500,01 - $1000,00'),
#   Text(3, 0, '$1000,01 - $1500,00'),
#   Text(4, 0, '$1500,01 - $2000,00'),
#   Text(5, 0, 'More then $2000,00')])

# %%
# Activity: Show a plot of the response by income.

## Same as above, transforming the income, that comes in thousands of diferent values, in ranges of value, after...
## ...checking the range of values.

print(numerical_df["income"].min())
print(numerical_df["income"].max())

def ranges_income(value):
    if value > 0 and value <= 15000:
        return 0
    elif value > 15000 and value <= 30000:
        return 1
    elif value > 30000 and value <= 45000:
        return 2
    elif value > 45000 and value <= 60000:
        return 3
    elif value > 60000 and value <= 80000:
        return 4
    else:
        return 5


clean_df["income"] = list(map(ranges_income, clean_df["income"]))
# Out:
# 10037
# 99981

# %%
## Then created the graphic using "hue", since working with two variables.

sns.countplot(x='income', hue='response', data=clean_df)
plt.xlabel("Income")
plt.ylabel("Count")
plt.legend(title="Response", loc="upper right",fontsize=8)
plt.title("Response by income")
plt.xticks(ticks=np.arange(6),labels=["$0 - $15.000,00", "$15.000,01 - $30.000,00","$30.000,01 - $45.000,00","$45.000,01 - $60.000,00","$60.000,01 - $80.000,00", "More then $80.000,00"],rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7fcd30908940>,
# ...
#  [Text(0, 0, '$0 - $15.000,00'),
#   Text(1, 0, '$15.000,01 - $30.000,00'),
#   Text(2, 0, '$30.000,01 - $45.000,00'),
#   Text(3, 0, '$45.000,01 - $60.000,00'),
#   Text(4, 0, '$60.000,01 - $80.000,00'),
#   Text(5, 0, 'More then $80.000,00')])

# %%
# Optional activity: plot any interesting findings/insights(minimum three) that describe some interesting facts... 
# ... about your data set and its input variables as well as relationships with the target feature.

pie_region = clean_df['region'].value_counts()
pie_region
labels = ["west region", "central", "north west", "east"]
plt.pie(pie_region, labels = labels, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcd307f7370>,
# ...
#  [Text(0.5174935809533753, 0.9706700745732572, 'west region'),
#   Text(-1.0967403160108071, 0.0846207967140164, 'central'),
#   Text(0.1532292052540988, -1.089275360346133, 'north west'),
#   Text(1.0592507389966614, -0.2966274969301176, 'east')],
#  [Text(0.28226922597456827, 0.5294564043126857, '34%'),
#   Text(-0.5982219905513493, 0.04615679820764531, '29%'),
#   Text(0.0835795665022357, -0.5941501965524361, '28%'),
#   Text(0.5777731303618152, -0.16179681650733685, '9%')])

# %%
sns.countplot(x='total_claim_amount', hue='region', data=clean_df)
plt.xlabel("Total claim amount")
plt.ylabel("Count")
plt.legend(title="Region")
plt.title("Total Claim Amount per Region")
plt.xticks(ticks=np.arange(6),labels=["$0 - $100,00", "$100,01 - $500,00","$500,01 - $1000,00","$1000,01 - $1500,00","$1500,01 - $2000,00", "More then $2000,00"],rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7fcd30829970>,
# ...
#  [Text(0, 0, '$0 - $100,00'),
#   Text(1, 0, '$100,01 - $500,00'),
#   Text(2, 0, '$500,01 - $1000,00'),
#   Text(3, 0, '$1000,01 - $1500,00'),
#   Text(4, 0, '$1500,01 - $2000,00'),
#   Text(5, 0, 'More then $2000,00')])

# %%
## The regions that participate more in the total clients also seem to claim more in each range of claiming value...
## ... therfore, region doesn't seem to play a big role in the claim amount configuration.

# %%
claim_per_region = clean_df.groupby(['total_claim_amount', 'gender', 'region'])['region'].count().rename('count').reset_index()

claim_female = claim_per_region[claim_per_region['gender'] == "f"]
claim_male = claim_per_region[claim_per_region['gender'] == 'm']
                           
fig, axes = plt.subplots(1,2,figsize=(16,6))

sns.barplot(x='total_claim_amount', y='count', hue = 'region', data = claim_female, ax = axes[0])
axes[0].set_title('Female')
sns.barplot(x='total_claim_amount', y='count', hue = 'region', data = claim_male, ax = axes[1])
axes[1].set_title('Male')
# Out:
# Text(0.5, 1.0, 'Male')

# %%
## The distribution of the total claim amount per region seems to be fairly the same for men and women, so the...
## ...sex doesn't seem to play an important role in the total claim.

# %%
g =sns.scatterplot(x="total_claim_amount", y="monthly_premium_auto", data=clean_df2)

# %%
## There is some connection between the amount payed monthly by the client and the total claim.
